# %%
import os
import torch
import torchaudio
from IPython.display import Audio
import numpy as np
from scipy.fft import fft, ifft
import matplotlib.pyplot as plt
import pandas as pd

# %%
wav_path = '/Users/ginoprasad/autotune/m4a_files/New Recording.m4a'

# %%
wav, sample_rate = torchaudio.load(wav_path)
wav = wav[0]
wav = wav[200000:400000]
Audio(wav, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
N = len(wav)

# %%
fourier_transform = fft(wav.numpy())

# %%
sample_rate
# Out:
# 48000

# %%
f = 440

# %%
test = np.sin((2 * np.pi * f / sample_rate) * np.arange(N))
Audio(test, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
f_test = fft(test)

# %%
new = 880 * 2

# %%
index = (N * new) / sample_rate

# %%
index
# Out:
# 7333.333333333333

# %%
f_test[np.floor(index).astype(int):np.floor(index).astype(int) + 1] += 80000

# %%
Audio(np.real(ifft(f_test)), rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Note Frequencies

# %%
prelim_notes_octave = 4
prelim_notes = [("C", 261.63), ("C#", 277.18), ("D", 293.66), ("D#", 311.13),
         ("E", 329.63), ("F", 349.23), ("F#", 369.99), ("G", 392.00), ("G#", 415.30), ("A", 440.00), ("A#", 466.16), ("B", 493.88), ]
prelim_notes
# Out:
# [('C', 261.63),
#  ('C#', 277.18),
#  ('D', 293.66),
#  ('D#', 311.13),
#  ('E', 329.63),
#  ('F', 349.23),
#  ('F#', 369.99),
#  ('G', 392.0),
#  ('G#', 415.3),
#  ('A', 440.0),
#  ('A#', 466.16),
#  ('B', 493.88)]

# %%
notes = [(freq * (2 ** (octave - prelim_notes_octave)), f"{name}{octave}") for octave in range(8) for name, freq in prelim_notes]
pd.DataFrame(notes)
# Out:
#               0    1
# 0     16.351875   C0
# 1     17.323750  C#0
# 2     18.353750   D0
# 3     19.445625  D#0
# 4     20.601875   E0
# ..          ...  ...
# 91  3136.000000   G7
# 92  3322.400000  G#7
# 93  3520.000000   A7
# 94  3729.280000  A#7
# 95  3951.040000   B7
#
# [96 rows x 2 columns]

# %%
kmer = 0.25 # seconds

# %%
threshold = 10000 # Hz

# %%
for i in range(0, N, int(kmer * sample_rate)):
    wav_slice = wav[i:i + int(kmer * sample_rate)]
    fourier_transform = fft(wav_slice.numpy())
    
    break

# %%
def autotune(wav_f):
    prev = 1
    for i, note in notes

# %%
plt.plot(fourier_transform)
# Out:
# /Users/ginoprasad/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
Audio(wav_slice, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
