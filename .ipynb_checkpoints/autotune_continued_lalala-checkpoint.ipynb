# %%
import os
import torch
import torchaudio
from IPython.display import Audio
import numpy as np
from scipy.fft import fft, ifft
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import random
from collections import Counter
from tqdm import tqdm
from matplotlib.pyplot import imshow

# %%
import Phase_Vocoder as pv
import yin_pitch_prediction as yin

# %% [markdown]
# # Loading Sample

# %%
wav_path = '/Users/ginoprasad/autotune/m4a_files/lalala.m4a'

# %%
sample, sample_rate = torchaudio.load(wav_path)
sample = sample[0].numpy()
sample = sample[int(sample_rate*12.25):][:int(sample_rate*5.25)]

# %%
Audio(sample, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def notes_in_scale(root, major=True):
    pattern = [True, False, True, False, True, True, False, True, False, True, False, True]
    scale = pd.DataFrame(yin.prelim_notes)[0]
    index = list(scale).index(root)
    if not major:
        index += 3
        index %= len(scale)
    scale = np.concatenate([scale[index:], scale[:index]])[pattern]
#     print(scale)
    return [x for x in yin.notes if any(x[1][:-1] == y for y in scale)]

# %%
def autotune(wav_slice, scale=None, precision=1000, max_scale=0.5, log=False, freq=None):
    if freq is None:
        
    closest_index = np.argmin(np.abs(pd.DataFrame(scale)[0] - freq)) if freq is not None else None
    closest = pd.DataFrame(scale)[0][closest_index] if closest_index is not None else None
    if freq is None or np.abs(1-(freq/closest)) > max_scale:
        print("NO CLOSEST\n---------")
        return wav_slice[:int(k * sample_rate)].numpy(), None

    if log:
        print(f"CLOSEST: {pd.DataFrame(scale)[1][closest_index]}")
        print(f"Scaling by {(freq/closest)}")
        print('--------')
    
    corrected = torchaudio.functional.resample(wav_slice[:int(k * sample_rate)], orig_freq=precision, new_freq=int(precision * freq/closest)).numpy()
    return corrected, closest
# Out:
#   Input In [37]
#     closest_index = np.argmin(np.abs(pd.DataFrame(scale)[0] - freq)) if freq is not None else None
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# # Parameters

# %%
yin.W = 100

# %% [markdown]
# # Autotune

# %%
R = 1.2

# %%
prev_analysis = np.zeros((vocoder.W//2)+1)
prev_shifted = np.zeros_like(prev_analysis)
output = np.zeros_like(sample)
for start_index in tqdm(range(0, len(sample), vocoder.H)):
    splice = sample[start_index:start_index+vocoder.W]
    
    freq = yin.pitch_predict(splice)
    
    print(freq)
    if len(splice) < vocoder.W:
        break
    processed_splice, prev_analysis, prev_shifted = vocoder.pitch_shift(splice, R, prev_analysis, prev_shifted)
#     processed_splice = robotization(splice)
    output[start_index:start_index+len(splice)] += (vocoder.hann_window[:len(splice)] * processed_splice)
# Out:
#   0%|                                  | 0/1313 [00:00<?, ?it/s]
# [0.0082817  0.01067925 0.0131788  ... 0.22671218 0.21929243 0.20186731]
#   0%|                                  | 0/1313 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [46], in <cell line: 4>()
#       5 splice = sample[start_index:start_index+vocoder.W]
#       8 print(splice)
# ----> 9 freq = yin.pitch_predict(splice)
#      11 print(freq)
#      12 if len(splice) < vocoder.W:
#
# File ~/autotune/yin_pitch_prediction.py:169, in pitch_predict(wav_slice, iterations)
#     167 pitch_candidates = []
#     168 for t in randints(len(wav_slice)-int(W + np.ceil(sample_rate / max_frequency)), iterations):
# --> 169     pitch_ = pitch(wav_slice, t=t)
#     170     if pitch_ is not None:
#     171         pitch_candidates.append(pitch_)
#
# File ~/autotune/yin_pitch_prediction.py:137, in pitch(wav_slice, x_min_threshold, x_max_threshold, y_threshold, t, width, index)
#     136 def pitch(wav_slice, x_min_threshold=sample_rate//max_frequency, x_max_threshold=sample_rate//min_frequency, y_threshold=0.15, t=0, width=3, index=False):
# --> 137     ls, dist = normalized_d(wav_slice, t)
#     138     minimum = None
#     139     for x, val in enumerate(ls):
#
# File ~/autotune/yin_pitch_prediction.py:103, in normalized_d(wav_slice, t)
#     101 sum_ = 0
#     102 ret = []
# --> 103 distance = d(wav_slice, t)
#     104 for tau, dist in enumerate(distance):
#     105     if tau == 0:
#
# File ~/autotune/yin_pitch_prediction.py:90, in d(wav_slice, t)
#      88     wav_slice = wav_slice.numpy()
#      89 autocorrelation = scipy.signal.convolve(wav_slice[t:], wav_slice[t:t+int(W*sample_rate)][::-1], mode='valid')
# ---> 90 energy = scipy.signal.convolve(wav_slice[t:] * wav_slice[t:], np.ones(int(W*sample_rate)), mode='valid')
#      91 distance = (energy + energy[0]) - (2 * autocorrelation)
#      92 assert len(distance) > 10
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/scipy/signal/_signaltools.py:1408, in convolve(in1, in2, mode, method)
#    1405     method = choose_conv_method(volume, kernel, mode=mode)
#    1407 if method == 'fft':
# -> 1408     out = fftconvolve(volume, kernel, mode=mode)
#    1409     result_type = np.result_type(volume, kernel)
#    1410     if result_type.kind in {'u', 'i'}:
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/scipy/signal/_signaltools.py:667, in fftconvolve(in1, in2, mode, axes)
#     662 s2 = in2.shape
#     664 shape = [max((s1[i], s2[i])) if i not in axes else s1[i] + s2[i] - 1
#     665          for i in range(in1.ndim)]
# --> 667 ret = _freq_domain_conv(in1, in2, axes, shape, calc_fast_len=True)
#     669 return _apply_conv_mode(ret, s1, s2, mode, axes)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/scipy/signal/_signaltools.py:506, in _freq_domain_conv(in1, in2, axes, shape, calc_fast_len)
#     503     fft, ifft = sp_fft.fftn, sp_fft.ifftn
#     505 sp1 = fft(in1, fshape, axes=axes)
# --> 506 sp2 = fft(in2, fshape, axes=axes)
#     508 ret = ifft(sp1 * sp2, fshape, axes=axes)
#     510 if calc_fast_len:
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/scipy/fft/_backend.py:25, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      23 if fn is None:
#      24     return NotImplemented
# ---> 25 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/scipy/fft/_pocketfft/basic.py:215, in r2cn(forward, x, s, axes, norm, overwrite_x, workers, plan)
#     212     raise TypeError("x must be a real sequence")
#     214 shape, axes = _init_nd_shape_and_axes(tmp, s, axes)
# --> 215 tmp, _ = _fix_shape(tmp, shape, axes)
#     216 norm = _normalization(norm, forward)
#     217 workers = _workers(workers)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.9/site-packages/scipy/fft/_pocketfft/helper.py:134, in _fix_shape(x, shape, axes)
#     131 for n, axis in zip(shape, axes):
#     132     s[axis] = n
# --> 134 z = np.zeros(s, x.dtype)
#     135 z[index] = x[index]
#     136 return z, True
#
# KeyboardInterrupt:

# %%
Audio(output, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
